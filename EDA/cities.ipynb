# %%
import geopandas as gpd
import pandas as pd
from shapely import geometry
import os
import ast

from typing import Any, Dict, List, Union
import osmnx as ox

from srai.constants import REGIONS_INDEX
import time

from srai.constants import REGIONS_INDEX, WGS84_CRS
from srai.embedders import CountEmbedder
from srai.joiners import IntersectionJoiner
from srai.loaders.osm_loaders import OSMOnlineLoader, OSMPbfLoader
from srai.loaders.osm_loaders.filters import HEX2VEC_FILTER
from srai.regionizers import H3Regionizer, SlippyMapRegionizer
from srai.utils import geocode_to_region_gdf

# %%
query = ['Copenhagen Municipality', 'Frederiksberg Municipality', 'Tårnby Municipality', 'Dragør Municipality']
geocoded_gdf = ox.geocode_to_gdf(query=query, which_result=None,  by_osmid=False)
print(geocoded_gdf[['display_name']])
print('-'*40)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 2
#       1 query = ['Copenhagen Municipality', 'Frederiksberg Municipality', 'Tårnby Municipality', 'Dragør Municipality']
# ----> 2 geocoded_gdf = ox.geocode_to_gdf(query=query, which_result=None,  by_osmid=False)
#       3 print(geocoded_gdf[['display_name']])
#       4 print('-'*40)
#
# File ~/.local/lib/python3.10/site-packages/osmnx/geocoder.py:111, in geocode_to_gdf(query, which_result, by_osmid, buffer_dist)
#     109 gdf = gpd.GeoDataFrame()
#     110 for q, wr in zip(query, which_result):
# --> 111     gdf = pd.concat([gdf, _geocode_query_to_gdf(q, wr, by_osmid)])
#     113 # reset GeoDataFrame index and set its CRS
#     114 gdf = gdf.reset_index(drop=True)
#
# File ~/.local/lib/python3.10/site-packages/osmnx/geocoder.py:167, in _geocode_query_to_gdf(query, which_result, by_osmid)
# ...

# %%
query = "New York City, USA"
geocoded_gdf = ox.geocode_to_gdf(query=query, which_result=None,  by_osmid=False)
geocoded_gdf
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  MULTIPOLYGON (((-74.25884 40.49887, -74.25814 ...    40.91763   40.476578
#
#    bbox_east  bbox_west   place_id  osm_type  osm_id        lat        lon  \
# 0 -73.700233 -74.258843  306106444  relation  175905  40.712728 -74.006015
#
#               display_name     class            type  importance
# 0  New York, United States  boundary  administrative    1.017577

# %%
geocoded_gdf
# Out:
#                     geometry  bbox_north  bbox_south  bbox_east  bbox_west  \
# 0  POINT (32.85405 39.92079)   40.080789   39.760789  33.014048  32.694048
#
#     place_id osm_type    osm_id        lat        lon  \
# 0  309597692     node  25869410  39.920789  32.854048
#
#                                         display_name  class  type  importance
# 0  Ankara, Çankaya, Ankara, Central Anatolia Regi...  place  city    0.651835

# %%
from tqdm import tqdm
from datetime import datetime

cities = []
regions = []
with open('../data/cities.txt', 'r') as cities_file:
    for city in cities_file:
        print(city)
        city = city.replace("\n", "")
        query = None
        try:
            query = ast.literal_eval(city)
        except:
            query = city
        geocoded_gdf = ox.geocode_to_gdf(query=query, by_osmid=False, which_result=None)
        print(geocoded_gdf[['display_name']].iloc[0].item())
        print('-'*40)
# Out:
# Tirana, Albania
#
# Tiranë, Tirana Municipality, Tirana County, Central Albania, 1001-1028, Albania
# ----------------------------------------
# Yerevan, Armenia
#
# Yerevan, Armenia
# ----------------------------------------
# Vienna, Austria
#
# Vienna, Austria
# ----------------------------------------
# Baku, Azerbaijan
#
# Baku, Yasamal Raion, Baku City, Baku, Azerbaijan
# ----------------------------------------
# Minsk, Belarus
#
# Minsk, Belarus
# ----------------------------------------
# Brussels, Belgium
#
# Brussels, Brussels-Capital, Belgium
# ----------------------------------------
# Sarajevo, Bosnia and Herzegovina
#
# Sarajevo, Socijalno, Željeznička, Novo Sarajevo Municipality, City of Sarajevo, Sarajevo Canton, Federation of Bosnia and Herzegovina, Bosnia and Herzegovina
# ----------------------------------------
# Sofia, Bulgaria
#
# Sofia, Sofia City, Sofia-City, Bulgaria
# ----------------------------------------
# Zagreb, Croatia
#
# ...
