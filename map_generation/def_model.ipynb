# %%
from diffusers import AutoencoderKL, DDPMScheduler, StableDiffusionPipeline, UNet2DConditionModel, DiffusionPipeline
from transformers import CLIPTextModel

from config import BASE_MODEL_NAME

# %%
from turtle import forward


unet = UNet2DConditionModel(
    sample_size=64,  # the target image resolution
    layers_per_block=2,  # how many ResNet layers to use per UNet block
    block_out_channels=(
        128,
        128,
        256,
        256,
        512,
        512,
    ),  # the number of output channes for each UNet block
    down_block_types=(
        "DownBlock2D",  # a regular ResNet downsampling block
        "DownBlock2D",
        "DownBlock2D",
        "DownBlock2D",
        "AttnDownBlock2D",  # a ResNet downsampling block with spatial self-attention
        "DownBlock2D",
    ),
    up_block_types=(
        "UpBlock2D",  # a regular ResNet upsampling block
        "AttnUpBlock2D",  # a ResNet upsampling block with spatial self-attention
        "UpBlock2D",
        "UpBlock2D",
        "UpBlock2D",
        "UpBlock2D",
    ),
)
import torch.nn as nn
from diffusers.models.modeling_utils import ModelMixin
class MyUnet(ModelMixin, nn.Module):
    def __init__(self):
        super().__init__()
        self.config = org_unet.config
        self.m = nn.Linear(123,123)

    def forward(self, *args, **kwargs):
        print(kwargs["encoder_hidden_states"].shape)
        print(kwargs["cross_attention_kwargs"] is None)
        print(args[0].shape)
        print(args[1].shape)
        raise Exception

        
noise_scheduler = DDPMScheduler.from_pretrained(BASE_MODEL_NAME, subfolder="scheduler")
text_encoder = CLIPTextModel.from_pretrained(BASE_MODEL_NAME, subfolder="text_encoder")
vae = AutoencoderKL.from_pretrained(BASE_MODEL_NAME, subfolder="vae")
pipeline = DiffusionPipeline.from_pretrained(
            # BASE_MODEL_NAME,
            text_encoder=text_encoder,
            vae=vae,
            unet=MyUnet()
        )
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /tmp/ipykernel_15383/3655634970.py:51 in <module>                                                │
# │                                                                                                  │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_15383/3655634970.py'                        │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# TypeError: DiffusionPipeline.from_pretrained() missing 1 required positional argument:
# 'pretrained_model_name_or_path'

# %%
text_encoder(
    **pipeline.tokenizer(
        "Some random text",
        padding="max_length",
        truncation=True,
        return_tensors="pt",
    )
).last_hidden_state.shape
# Out:
# torch.Size([1, 77, 768])

# %%
pipeline(prompt="Some random text")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# torch.Size([2, 77, 768])
# True
# torch.Size([2, 4, 64, 64])
# torch.Size([])
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /tmp/ipykernel_15383/1704840086.py:1 in <module>                                                 │
# │                                                                                                  │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_15383/1704840086.py'                        │
# │                                                                                                  │
# │ /home/marcin/Documents/mgr/semestr_II/nlp/nlp_l2/nlp_venv/lib/python3.10/site-packages/torch/uti │
# │ ls/_contextlib.py:115 in decorate_context                                                        │
# │                                                                                                  │
# ...

# %%
org_unet = UNet2DConditionModel.from_pretrained(BASE_MODEL_NAME, subfolder="unet")

# %%
vae
# Out:
# AutoencoderKL(
#   (encoder): Encoder(
#     (conv_in): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (down_blocks): ModuleList(
#       (0): DownEncoderBlock2D(
#         (resnets): ModuleList(
#           (0-1): 2 x ResnetBlock2D(
#             (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#         (downsamplers): ModuleList(
#           (0): Downsample2D(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2))
#           )
#         )
#       )
#       (1): DownEncoderBlock2D(
#         (resnets): ModuleList(
#           (0): ResnetBlock2D(
# ...
